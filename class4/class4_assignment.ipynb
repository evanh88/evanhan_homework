# %% [markdown]
# # Class 4 Assignment

# %% [markdown]
# ## Search and download papers in cs.CL

# %%
from documents_downloading import get_latest_arxiv
get_latest_arxiv(query="cat:cs.CL", max_results=50)
# Out:
# /home/ehan/workspace/class4
# Found 50 papers matching the query 'cat:cs.CL'.
# dio: 2508.15763v1, Title: Intern-S1: A Scientific Multimodal Foundation Model
# dio: 2508.15760v1, Title: LiveMCP-101: Stress Testing and Diagnosing MCP-enabled Agents on Challenging Queries
# dio: 2508.15757v1, Title: Language-Guided Tuning: Enhancing Numeric Optimization with Textual Feedback
# dio: 2508.15754v1, Title: Dissecting Tool-Integrated Reasoning: An Empirical Study and Analysis
# dio: 2508.15746v1, Title: End-to-End Agentic RAG System Training for Traceable Diagnostic Reasoning
# dio: 2508.15721v1, Title: EcomMMMU: Strategic Utilization of Visuals for Robust Multimodal E-Commerce Models
# dio: 2508.15711v1, Title: Stemming -- The Evolution and Current State with a Focus on Bangla
# dio: 2508.15709v1, Title: Position Bias Mitigates Position Bias:Mitigate Position Bias Through Inter-Position Knowledge Distillation
# dio: 2508.15658v1, Title: Benchmarking Computer Science Survey Generation
# ...

# %% [markdown]
# ## Process the downloaded PDF files and generate FAISS index

# %%
from documents_processing import main
main()
# Out:
# Number of vectors in the FAISS index: 7720
# FAISS index created, populated, and saved!
# Query RepreGuard three other detectors
#
# Search results:
#
# Filename: 2508.15370v1.pdf, Page: 13, Distance: 1.2007542848587036
# Content: V. Initially, the
# RESA-7B model trained solely on the safety data in VLGuard
# ...
#
# Filename: 2508.15252v1.pdf, Page: 8, Distance: 1.2637683153152466
# Content: s normal and another is
# abnormal. Based on the previous detector [21], fguardianΦ(·) can
# be built through a TextCNN, an Encoder and a MLP, where the
# TextCNN enhanced by the Encoder are used to capture features
# from the profiles, and the MLP followed by a Sigmoid is
# TABLE II: Statistics of Datasets
# Dataset
# #Users
# #Items
# #Reviews
# Sparsity
# Amazon Musical Instruments
# 1,429
# 900
# 10,261
# 99.20%
# Amazon Automotive
# 2,928
# 1,835
# 20,473
# 99.62%
# Yelp
# 1,599
# 1,318
# 30,120
# 98.57%
# leveraged to perform detections bas...
#
# ...

# %% [markdown]
# ## Use the search API to find relevant papers

# %%
# Launch unicorn server which serves the search API
! uvicorn faiss_search:app --reload
# #!/usr/bin/env python3
# Out:
# INFO:     Will watch for changes in these directories: ['/home/ehan/workspace/class4']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [786741] using WatchFiles
# INFO:     Started server process [786743]
# INFO:     Waiting for application startup.
# FAISS index or documents file not found. Please ensure they are created before starting the server.
# INFO:     Application startup complete.
# INFO:     127.0.0.1:37050 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37054 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37054 - "GET /docs HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37054 - "GET /openapi.json HTTP/1.1" 200 OK
# INFO:     127.0.0.1:37056 - "POST /search/ HTTP/1.1" 500 Internal Server Error
# WARNING:  WatchFiles detected changes in 'search.py'. Reloading...
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# ...
